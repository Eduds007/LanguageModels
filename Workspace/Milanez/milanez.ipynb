# %%
import datasets

# %%
#carrega natural questions

from datasets import load_dataset
dataset = load_dataset('json', data_files="simplified-nq-train.jsonl")
# Out:
# Downloading data files: 100%|██████████| 1/1 [00:00<00:00, 3158.36it/s]
# Extracting data files: 100%|██████████| 1/1 [00:00<00:00, 11.65it/s]
# Generating train split: 307373 examples [02:19, 2210.56 examples/s]

# %%
#carrega modelo de tradução

from transformers import pipeline
pipe = pipeline("translation", model="Helsinki-NLP/opus-mt-tc-big-en-pt")
# Out:
# 2023-11-29 14:02:15.199794: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-11-29 14:02:15.422451: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-29 14:02:16.218130: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
df = pd.DataFrame(columns = ['title', 'context','question', 'answer'])

# %%
sample = dataset['train'][0]

# %%
titulo = sample['document_text']

# %%
re.findall(r'(?<=<h1>)(.+?)(?=</h1>)', titulo, re.IGNORECASE)[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/eduardo/Área de Trabalho/4_semestre/IC/LanguageModels/milanez.ipynb Célula 7 line 1
# ----> <a href='vscode-notebook-cell:/home/eduardo/%C3%81rea%20de%20Trabalho/4_semestre/IC/LanguageModels/milanez.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> re.findall(r'(?<=<h1>)(.+?)(?=</h1>)', titulo, re.IGNORECASE)[0]
#
# NameError: name 're' is not defined

# %%
sample['annotations']
# Out:
# [{'yes_no_answer': 'NONE',
#   'long_answer': {'start_token': 1952,
#    'candidate_index': 54,
#    'end_token': 2019},
#   'short_answers': [{'start_token': 1960, 'end_token': 1969}],
#   'annotation_id': 5.931654502200276e+17}]

# %%
doc = sample['document_text']

# %%
sample['annotations'][0]['long_answer']
# Out:
# {'start_token': 1952, 'candidate_index': 54, 'end_token': 2019}

# %%
init = sample['annotations'][0]['short_answers'][0]['start_token']
end = sample['annotations'][0]['short_answers'][0]['end_token']

# %%
" ".join(doc.split(" ")[init:end])
# Out:
# "a newsletter sent to an advertising firm 's customers"

# %%
#sample['question_text']
# Out:
# 'what happened to the lost settlement of roanoke'

# %%
import pandas as pd
import re
import sys
import time

# %%
def translate(size=10, dataset=dataset):
    df = pd.DataFrame(columns = ['title', 'question', 'long_answer', 'short_answer'])
    small_set = dataset['train']
    for i in range(size):

        doc = re.sub(r'''<(?:"[^"]*"['"]*|'[^']*'['"]*|[^'">])+>''','',small_set[i]['document_text'])
        init_long = small_set[i]['annotations'][0]['long_answer']['start_token']
        end_long = small_set[i]['annotations'][0]['long_answer']['end_token']
        if len(small_set[i]['annotations'][0]['short_answers']) != 0:
            init_short = small_set[i]['annotations'][0]['short_answers'][0]['start_token']
            end_short = small_set[i]['annotations'][0]['short_answers'][0]['end_token']
        else:
            init_short = 0
            end_short  = 0
        question = small_set[i]['question_text']
        long_answer = " ".join(doc.split(" ")[init_long:end_long])
        short_answer = " ".join(doc.split(" ")[init_short:end_short])
        title = re.findall(r'(?<=<h1>)(.+?)(?=</h1>)', small_set[i]['document_text'], re.IGNORECASE)[0]
        #if len(long_answer) > 0:  
            #title = pipe('>>por<< ' + title)[0]['translation_text']
            #long_answer= pipe('>>por<< ' + long_answer)[0]['translation_text']
            #if len(short_answer) != 0:
            #    short_answer= pipe('>>por<< ' + short_answer)[0]['translation_text']
            #question= pipe('>>por<< ' + question)[0]['translation_text']

            
            
        #else:
        #    pass
            
        new_row = {'title': [title], 'question': [question], 'long_answer': [long_answer], 'short_answer': [short_answer]}
        df_aux = pd.DataFrame(new_row)
        df = pd.concat([df, df_aux])

        #configuração do terminal
        sys.stdout.write(f'\rProgress : {((i+1)/size)*100}%')
        sys.stdout.flush()
        
    df = df.loc[df['long_answer'] != '']
    df.reset_index(drop=True, inplace=True)
    df
    return df
    
translate(1000, dataset=dataset).to_excel('saida.xlsx')
# Out:
# Progress : 100.0%99999999999%%

# %%
# %%time
traduzido = translate(size=20)
# Out:
# Progress : 100.0%00000000001%Wall time: 1min 51s

# %%
squad = {
    "version": "0.1",
    "data": [
        
    ],
}

# %%
import json
# Load the Excel spreadsheet
traduzido = pd.read_excel('../../2. Seleção de modelos e dados/Modelo Opus/nq-traduzido-opus-5k.xlsx')
for passage in json.loads(traduzido.to_json(orient='records')):
    estrutura = {
        "title": passage['title'],
        "paragraphs": [
            {
            "context": passage['long_answer'],
            "qas": [
                {
                    "id":0,
                    "question": passage['question'],
                    "answers": [
                        {
                        "answer_start":0,
                        'text':passage['short_answer'],
                        }
                        
                    ],
                },
            ],
            },
        ],
    }
    squad['data'].append(estrutura)

# %%
squad
# Out:
# {'data': [{'title': 'E-mail marketing',
#    'paragraphs': [{'context': 'Um exemplo comum de marketing de permissão é uma newsletter enviada aos clientes de uma empresa de publicidade. Essas newsletters informam os clientes sobre os próximos eventos ou promoções, ou novos produtos. Neste tipo de publicidade, uma empresa que deseja enviar uma newsletter aos seus clientes pode perguntar-lhes no ponto de compra se eles gostariam de receber a newsletter.',
#      'qas': [{'id': 0,
#        'question': 'que é o uso mais comum de marketing por e-mail opt-in',
#        'answers': [{'answer_start': 0,
#          'text': 'uma newsletter enviada aos clientes de uma empresa de publicidade'}]}]}]},
#   {'title': 'A Mãe (Como Eu Conheci Sua Mãe)',
#    'paragraphs': [{'context': "Tracy McConnell , mais conhecido como  The Mother '' , é o personagem-título da sitcom de televisão da CBS How I Met Your Mother . O show , narrado por Future Ted , conta a história de como Ted Mosby conheceu The Mother . Tracy McConnell aparece em 8 episódios de  Lucky Penny '' para  The Time Travelers '' como um personagem invisível ; ela foi vista pela primeira vez em  Something New '' e foi promovida a 9 a personagem principal.",
#      'qas': [{'id': 0,
#        'question': 'como i.met sua mãe que é a mãe',
#        'answers': [{'answer_start': 0, 'text': 'Tracy McConnell'}]}]}]},
#   {'title': 'Fertilização humana',
#    'paragraphs': [{'context': 'O processo de fertilização envolve uma fusão de espermatozóides com um óvulo. A sequência mais comum começa com a ejaculação durante a cópula, segue com a ovulação e termina com a fertilização. Várias exceções a essa sequência são possíveis, incluindo inseminação artificial, fertilização in vitro, ejaculação externa sem cópula ou cópula logo após a ovulação. Ao encontrar o oócito secundário, o acrossomo do espermatozóide pr',
#      'qas': [{'id': 0,
#        'question': 'Que tipo de fertilização ocorre em humanos',
#        'answers': [{'answer_start': 0, 'text': None}]}]}]},
#   {'title': 'Lista de quarterbacks de carreira da Liga Nacional de Futebol ganha líderes',
#    'paragraphs': [{'context': 'O quarterback ativo Tom Brady detém os recordes de mais vitórias com 220, a maioria das vitórias na temporada regular com 195 e a maioria das vitórias na pós-temporada com 25, a partir da semana 16 da temporada 2017 da NFL. Tendo jogado a totalidade de sua carreira com o New England Patriots, cada um dos registros de vitórias de Brady também se aplicam a vitórias com uma única equipe.',
#      'qas': [{'id': 0,
#        'question': 'quem teve mais vitórias na nfl',
#        'answers': [{'answer_start': 0, 'text': 'Tom Brady'}]}]}]},
#   {'title': 'Pom Klementieff',
#    'paragraphs': [{'context': "Pom Klementieff (nascido em 3 de maio de 1986 ) é uma atriz francesa. Ela foi treinada na escola de teatro Cours Florent em Paris e apareceu em filmes como Loup ( 2009 ) , Sleepless Night ( 2011 ) e Hacker's Game ( 2015 ) . Ela interpreta o papel de Mantis no filme Guardiões da Galáxia Vol. 2 ( 2017 ) e aparecerá no mesmo papel no Infinity War ( 2017 ) .",
#      'qas': [{'id': 0,
#        'question': 'quem jogou mantis guardiões da galáxia 2',
#        'answers': [{'answer_start': 0, 'text': 'Pom Klementieff'}]}]}]},
#   {'title': 'História dos Acadianos',
#    'paragraphs': [{'context': "A sobrevivência dos assentamentos acadianos foi baseada na cooperação bem-sucedida com os povos indígenas da região. Nos primeiros anos do assentamento acadiano , isso incluiu um pequeno número de casamentos registrados entre colonos acadianos e mulheres indígenas . Alguns registros sobreviveram mostrando casamentos entre colonos acadianos e mulheres indígenas em ritos católicos romanos formais , por exemplo, o casamento de Charles La Tour com uma mulher Mi'kmaw em 1626",
#      'qas': [{'id': 0,
#        'question': 'que tribo indígena os acadianos formaram amizades e alianças com',
#        'answers': [{'answer_start': 0, 'text': None}]}]}]},
#   {'title': 'Vice-Ministro-Chefe de Jammu e Caxemira',
#    'paragraphs': [{'context': 'Vice-Ministro-Chefe de Jammu e Caxemira Incumbent Vacant desde 20 de junho de 2018 Governador interino de Jammu e Caxemira Titular inaugural Bakshi Ghulam Mohammad (como Vice-Primeiro-Ministro) Formação 5 de março de 1948',
#      'qas': [{'id': 0,
#        'question': 'quem é vice cm de j e k',
#        'answers': [{'answer_start': 0, 'text': None}]}]}]},
#   {'title': 'som Nashville',
#    'paragraphs': [{'context': 'No início dos anos 1960, o som de Nashville começou a ser desafiado pelo som rival Bakersfield no lado do país e pela Invasão Britânica no lado pop; agravando esses problemas foram as mortes súbitas, em acidentes de avião separados, de Patsy Cline e Jim Reeves, duas das maiores estrelas do Nashville Sound.',
#      'qas': [{'id': 0,
#        'question': 'o som nashville trouxe um som polido e cosmopolita para a música country por',
#        'answers': [{'answer_start': 0,
#          'text': 'o uso de arranjos de cordas exuberantes com uma orquestra real e, muitas vezes, vocais de fundo fornecidos por um coro'}]}]}]},
#   {'title': 'Lista de emissoras da Premier League',
#    'paragraphs': [{'context': 'Country Language Broadcasters Albânia Albanês SuperSport Kosovo Sérvio Croata Macedónio Esloveno Desporto Klub Croácia Bósnia e Herzegovina Montenegro Macedónia Eslovénia Andorra Espanhol Movistar+ Arménia Arménia Arménia 2 Áustria Alemão DAZN Azerbaijão Azerbaijão AzTV Belarusian Beltradio Belgium Dutch French Play Sports VOO Sport Bulg',
#      'qas': [{'id': 0,
#        'question': 'em que canal é a primeira liga em França',
#        'answers': [{'answer_start': 0, 'text': 'SFR Sport'}]}]}]},
#   {'title': 'Kit de desenvolvimento Java',
#    'paragraphs': [{'context': 'O Java Development Kit (JDK) é uma implementação de qualquer uma das plataformas Java , Standard Edition , Java Platform , Enterprise Edition , ou Java Platform , Micro Edition plataformas lançadas pela Oracle Corporation na forma de um produto binário destinado a desenvolvedores Java em Solaris , Linux , macOS ou Windows . O JDK inclui uma JVM privada e alguns outros recursos para terminar o desenvolvimento de um aplicativo Java .',
#      'qas': [{'id': 0,
#        'question': 'Qual é o uso do jdk no java',
#        'answers': [{'answer_start': 0, 'text': None}]}]}]},
#   {'title': 'Permissão do aluno',
#    'paragraphs': [{'context': 'Normalmente , um condutor que opere com a autorização de um aluno deve ser acompanhado por um condutor adulto licenciado com pelo menos 21 anos de idade ou mais e no banco do passageiro do veículo em todos os momentos .',
#      'qas': [{'id': 0,
#        'question': 'quem precisa estar no carro com um motorista de licença',
#        'answers': [{'answer_start': 0,
#          'text': 'Um condutor adulto licenciado com pelo menos 21 anos de idade ou mais e no banco do passageiro do veículo em todos os momentos'}]}]}]},
#   {'title': 'Deus não está morto: uma luz nas trevas',
#    'paragraphs': [{'context': 'A fotografia principal foi concluída em Little Rock , Arkansas , em dezembro de 2017 . Foi lançado nos Estados Unidos em 30 de março de 2018 . Ao contrário dos dois primeiros filmes , A Light in Darkness foi uma bomba de bilheteria , fazendo menos em toda a sua exibição teatral ( US $ 5,7 milhões ) do que os outros arrecadados em seus respectivos fins de semana de abertura ( US $ 9,7 milhões e US $ 7,6 milhões ) .',
#      'qas': [{'id': 0,
#        'question': 'Deus não está morto, uma luz na escuridão',
#        'answers': [{'answer_start': 0, 'text': '30 de março de 2018'}]}]}]},
#   {'title': 'Presidente da Assembleia Geral das Nações Unidas',
#    'paragraphs': [{'context': 'Miroslav Lajk, da Eslováquia, foi eleito Presidente da Assembleia Geral das Nações Unidas da sua 72a sessão, com início em setembro de 2017.',
#      'qas': [{'id': 0,
#        'question': 'que é o atual presidente da Assembleia Geral da ONU',
#        'answers': [{'answer_start': 0,
#          'text': 'Miroslav Lajk da Eslováquia'}]}]}]},
#   {'title': 'Powerball',
#    'paragraphs': [{'context': 'Desenhos para Powerball são realizados todas as quartas e sábados à noite às 10: 59 p.m. Eastern Time . Desde 7 de outubro de 2015 , o jogo usou uma matriz de 5 / 69 (bolas brancas) + 1 / 26 (Powerballs ) a partir da qual os números vencedores são escolhidos, resultando em chances de 1 em 292,201,338 de ganhar um jackpot por jogo . Cada jogo custa US $ 2, ou US $ 3 com a opção Powerball.',
#      'qas': [{'id': 0,
#        'question': 'quando eles puxam os números de powerball 2016',
#        'answers': [{'answer_start': 0,
#          'text': 'todas as quartas-feiras e sábados à noite às 10 : 59 p.m.'}]}]}]},
#   {'title': 'Eclipse solar de 21 de agosto de 2017',
#    'paragraphs': [{'context': 'Eclipse solar de 21 de agosto de 2017 Totalidade vista de Simpsonville , Carolina do Sul Mapa Tipo de eclipse Natureza Total Gama 0.4367 Magnitude 1.0306 Eclipse máximo Duração 160 seg ( 2 m 40 s ) 37 ° 00  N 87 ° 42  W / 37 ° N 87.7 ° W / 37 ; - 87.7 Max . largura da banda 115 km ( 71 mi ) Vezes ( UTC )',
#      'qas': [{'id': 0,
#        'question': 'Quando o eclipse deve ocorrer',
#        'answers': [{'answer_start': 0, 'text': '21 de agosto de 2017'}]}]}]},
#   {'title': 'Dubai',
#    'paragraphs': [{'context': 'Dubai ( / duba / doo - BY ; árabe :  Dubay , pronúncia do Golfo : ( dbj ) ) é a maior e mais populosa cidade nos Emirados Árabes Unidos ( Emirados Árabes Unidos ) . Ele está localizado na costa sudeste do Golfo Pérsico e é a capital do Emirado de Dubai , um dos sete emirados que compõem o país .',
#      'qas': [{'id': 0,
#        'question': 'Qual é o nome do mar em torno de Dubai',
#        'answers': [{'answer_start': 0, 'text': 'Golfo Pérsico'}]}]}]},
#   {'title': 'Lista de líderes de pontuação de carreira da National Basketball Association',
#    'paragraphs': [{'context': 'Posição do Jogador Rank ( s ) Equipe ( s ) jogou por ( anos ) Total de pontos Jogos jogados Pontos por jogo média Field goals made Three - point field goals made Free throws made Abdul - Jabbar , Kareem Kareem Abdul - Jabbar * Milwaukee Bucks ( 1969 - 1975 ) Los Angeles Lakers ( 1975 - 1989 ) 38,387 1.560 24,6 15,837 6.712 Malone 2003 Malone ( Karl Malone )',
#      'qas': [{'id': 0,
#        'question': 'que detém o recorde de nba para a maioria dos pontos em uma carreira',
#        'answers': [{'answer_start': 0, 'text': 'Kareem Abdul-Jabbar'}]}]}]},
#   {'title': 'Once Upon a Time (6a temporada)',
#    'paragraphs': [{'context': "No. geral No. na temporada Título Dirigido por Escrito por Original data do ar espectadores dos EUA ( milhões ) 112  O Salvador '' Eagle Egilsson Edward Kitsis & Adam Horowitz 25 de setembro de 2016 ( 2016 - 09 - 25 ) 3.99 No passado, Aladdin , um  Salvador '' , é insultado por Jafar sobre a queda inevitável de todos os Salvadores . Em Storybrooke as experiências de terra.",
#      'qas': [{'id': 0,
#        'question': 'Uma vez uma lista de episódios da 6a temporada',
#        'answers': [{'answer_start': 0, 'text': None}]}]}]},
#   {'title': 'Leis de armas na Geórgia',
#    'paragraphs': [{'context': 'A Geórgia retribui no reconhecimento de licenças de armas de fogo com os seguintes estados: Alabama , Alasca , Arizona , Arkansas , Colorado , Flórida , Idaho , Indiana , Iowa , Kansas , Kentucky , Louisiana , Maine , Michigan , Mississippi , Missouri , Montana , New Hampshire , Carolina do Norte , Dakota do Norte , Ohio , Oklahoma , Pensilvânia , Carolina do Sul , Dakota do Sul , Tennessee e Virgínia do Texas .',
#      'qas': [{'id': 0,
#        'question': 'onde está uma georgia escondida licença de transporte válida',
#        'answers': [{'answer_start': 0, 'text': None}]}]}]},
#   {'title': 'Maze Runner: A Cura da Morte',
#    'paragraphs': [{'context': "Maze Runner: The Death Cure foi originalmente lançado em 17 de fevereiro de 2017, nos Estados Unidos pela 20th Century Fox, mas o estúdio reescalonou o lançamento do filme para 26 de janeiro de 2018 nos cinemas e IMAX, dando tempo para O'Brien se recuperar de lesões que sofreu durante as filmagens. O filme recebeu críticas mistas dos críticos e arrecadou mais de US $ 272 milhões em todo o mundo.",
#      'qas': [{'id': 0,
#        'question': 'Quando saiu o novo filme do corredor do labirinto',
#        'answers': [{'answer_start': 0, 'text': '26 de janeiro de 2018'}]}]}]},
#   {'title': 'Caixa lacrosse',
#    'paragraphs': [{'context': "Durante o jogo , uma equipe consiste em seis jogadores : um goleiro e cinco  corredores '' . Um corredor é qualquer jogador de posição não goleiro , incluindo atacantes , jogadores de transição , e defensores . Os corredores geralmente se especializam em um desses papéis e substituem fora do campo quando a bola se move de uma extremidade para a outra . Quando o esporte originou equipes jogadas com seis corredores . No entanto , em 1953, o sexto lugar foi chamado de rover.",
#      'qas': [{'id': 0,
#        'question': 'Quantos jogadores em uma equipe de box lacrosse',
#        'answers': [{'answer_start': 0, 'text': 'seis'}]}]}]},
#   {'title': 'Lista de cidades-sede dos Jogos Olímpicos',
#    'paragraphs': [{'context': 'Esta é uma lista de cidades-sede dos Jogos Olímpicos , tanto no verão como no inverno , desde que os Jogos Olímpicos modernos começaram em 1896 . Desde então , os jogos de verão geralmente - mas nem sempre - celebraram um período de quatro anos conhecido como Olimpíada . Houve 28 Jogos Olímpicos de Verão realizados em 24 cidades , e 23 Jogos Olímpicos de Inverno realizados em 20 cidades . Além disso , três edições de verão e duas de inverno dos Jogos foram programadas para ocorrer mais tarde .',
#      'qas': [{'id': 0,
#        'question': 'Onde estão os próximos Jogos Olímpicos a serem realizados',
#        'answers': [{'answer_start': 0,
#          'text': 'Tóquio para os Jogos Olímpicos de Verão de 2020'}]}]}]},
#   {'title': 'Regra de três segundos',
#    'paragraphs': [{'context': 'A regra três - segunda foi introduzida em 1936 e foi expressa como tal: nenhum jogador ofensivo com a bola poderia permanecer na Chave com ou sem a bola, por mais de três segundos.',
#      'qas': [{'id': 0,
#        'question': 'quando a regra nba 3 segundos começou',
#        'answers': [{'answer_start': 0, 'text': '1936'}]}]}]},
#   {'title': 'Sinais de mais e menos',
#    'paragraphs': [{'context': "Na Europa, no início do século XV, as letras  P '' e  M '' foram geralmente usadas. Os símbolos ( P com linha p  para pi , ou seja, mais , e M com linha m  para menor , ou seja , menos ) apareceu pela primeira vez em Luca Pacioli 's matemática compêndio , Summa de aritmética , geometria ,",
#      'qas': [{'id': 0,
#        'question': 'quando os sinais de mais e menos foram registrados pela primeira vez',
#        'answers': [{'answer_start': 0, 'text': None}]}]}]},
#   {'title': 'O Bob é o teu tio.',
#    'paragraphs': [{'context': "... E o seu tio de Bob é uma expressão de origem desconhecida, que significa  e lá está '' ou  e lá está você. '' É comumente usado na Grã-Bretanha e nos países da Commonwealth. Normalmente, alguém diz que para concluir um conjunto de instruções simples ou quando um resultado é alcançado. O significado é semelhante ao da expressão francesa  et voilà! ''",
#      'qas': [{'id': 0,
#        'question': "de onde vem a frase bob's your tio",
#        'answers': [{'answer_start': 0, 'text': None}]}]}]},
#   {'title': 'Aquele com a proposta',
#    'paragraphs': [{'context': 'Depois de procurar o dia todo , Chandler corre de volta para seu apartamento e quando ele chega lá , Joey encontra-o no corredor , alegando Monica o deixou por causa de seus problemas de compromisso . Quando Chandler entra em seu apartamento , com medo de Monica realmente sair , ele descobre que está longe de ser abandonado , há velas acesas por toda parte e Monica está ajoelhada para propor . No meio de propor a Chandler , ela chora de pura emoção ,',
#      'qas': [{'id': 0,
#        'question': 'aquele em que chandler e monica ficam noivos',
#        'answers': [{'answer_start': 0, 'text': None}]}]}]},
#   {'title': 'So You Think You Can dance: the next Generation (tradução)',
#    'paragraphs': [{'context': "So You Think You Can Dance : The Next Generation Temporada 13 Transmissão de 30 de maio - 12 de setembro de 2016 Juízes Nigel Lythgoe Paula Abdul Jason Derulo Maddie Ziegler Host (s ) Cat Deeley Broadcaster Fox Winner Leon  Kida '' Burns Gênero (s ) Hip - Hop Runner - up J.T. Igreja Cronologia  2016",
#      'qas': [{'id': 0,
#        'question': 'Quem ganhou para que você pense que pode dançar 2016',
#        'answers': [{'answer_start': 0, 'text': "Leon  Kida '' Burns"}]}]}]},
#   {'title': 'Bates Motel ( série de TV )',
#    'paragraphs': [{'context': 'Freddie Highmore como Norman Bates',
#      'qas': [{'id': 0,
#        'question': 'que toca norman bates no programa de TV',
#        'answers': [{'answer_start': 0, 'text': 'Freddie Highmore'}]}]}]},
#   {'title': 'Tráfego de mão esquerda - e direita',
#    'paragraphs': [{'context': 'No final dos anos 1700, o tráfego nos Estados Unidos foi RHT com base no uso de grandes vagões de carga puxados por vários pares de cavalos. Os vagões não tinham assento do motorista, então o (normalmente destro) postilion segurou seu chicote em sua mão direita e, assim, sentou-se no cavalo traseiro esquerdo . Sentado à esquerda , o motorista preferiu que outros vagões passassem à esquerda para que ele pudesse ter certeza.',
#      'qas': [{'id': 0,
#        'question': 'Quando é que eu comecei a conduzir à direita',
#        'answers': [{'answer_start': 0, 'text': 'tarde 1700s'}]}]}]},
#   {'title': 'Sistema nervoso central',
#    'paragraphs': [{'context': 'O sistema nervoso central (SNC) é a parte do sistema nervoso que consiste no cérebro e na medula espinhal . O sistema nervoso central é assim chamado porque integra informações que recebe de , e coordena e influencia a atividade de , todas as partes dos corpos de animais bilateralmente simétricos - isto é, todos os animais multicelulares, exceto esponjas e animais radialmente simétricos, como águas-vivas - e contém a maioria dos nervos',
#      'qas': [{'id': 0,
#        'question': 'Nomear alguns componentes do sistema nervoso central (snc)',
#        'answers': [{'answer_start': 0, 'text': 'cérebro'}]}]}]},
#   {'title': 'The Price Is Right (em inglês).',
#    'paragraphs': [{'context': 'A equipe de produção do game show de Mark Goodson e Bill Todman foi responsável por produzir o original, bem como as versões revival do game show . Goodson - Todman funcionário Bob Stewart é creditado com a criação da versão original de The Price Is Right . Roger Dobkowitz foi o produtor de 1984 a 2008, tendo trabalhado com o programa como um funcionário de produção desde a estréia do show depois de se formar na San Francisco State University .',
#      'qas': [{'id': 0,
#        'question': 'Quem é o diretor do preço está certo',
#        'answers': [{'answer_start': 0, 'text': 'Adam Sandler'}]}]}]},
#   {'title': 'A ponte no rio Kwai',
#    'paragraphs': [{'context': 'The Bridge on the River Kwai é um filme de guerra épico britânico-americano de 1957 dirigido por David Lean e estrelado por William Holden , Jack Hawkins , e Alec Guinness , e com Sessue Hayakawa . Baseado no romance Le Pont de la Rivire Kwai ( 1952 ) por Pierre Boulle , o filme é uma obra de ficção , mas agora empresta a construção da Ferrovia Burma em 1942 - 1943.',
#      'qas': [{'id': 0,
#        'question': 'ponte no rio kwai fato ou ficção',
#        'answers': [{'answer_start': 0, 'text': 'ficção'}]}]}]},
#   {'title': 'Comunidade das Nações',
#    'paragraphs': [{'context': 'A transferência de soberania sobre Hong Kong em 1997 terminou os laços da colônia com a Commonwealth através do Reino Unido . O governo de Hong Kong , como uma região administrativa especial da China , não seguiu a adesão . Hong Kong, no entanto, continuou a participar de algumas das organizações da família Commonwealth , como a Commonwealth Lawyers Association (sediou a Commonwealth Lawyers Conference em 1983 e 2009 ) , a Commo',
#      'qas': [{'id': 0,
#        'question': 'é hong kong uma parte da comunidade',
#        'answers': [{'answer_start': 0, 'text': None}]}]}]},
#   {'title': 'Pulso',
#    'paragraphs': [{'context': 'Na medicina, um pulso representa a palpação arterial tátil do batimento cardíaco por dedos treinados. O pulso pode ser palpado em qualquer lugar que permita que uma artéria seja comprimida perto da superfície do corpo, como no pescoço (artéria carótida), pulso (artéria radial), na virilha (artéria femoral), atrás do joelho (artéria poplítea), perto da articulação do tornozelo (artéria do quadril) e do joelho (artéria do quadril).',
#      'qas': [{'id': 0,
#        'question': 'Onde o pulso pode ser sentido no corpo',
#        'answers': [{'answer_start': 0, 'text': None}]}]}]},
#   {'title': 'Guerra das Malvinas',
#    'paragraphs': [{'context': 'A Guerra das Malvinas, também conhecida como Conflito das Malvinas, Crise das Malvinas, Guerra das Malvinas, Conflito do Atlântico Sul e Guerra do Atlântico Sul, foi uma guerra de dez semanas entre a Argentina e o Reino Unido sobre dois territórios dependentes britânicos no Atlântico Sul.',
#      'qas': [{'id': 0,
#        'question': 'Por que a Argentina atacou as ilhas Falklands/Malvinas?',
#        'answers': [{'answer_start': 0,
#          'text': 'uma tentativa de estabelecer a soberania que reivindicou sobre eles.'}]}]}]},
#   {'title': 'rbita da Lua',
#    'paragraphs': [{'context': 'rbita da Lua Diagrama da órbita da Lua em relação ao Valor de Propriedade da Terra Eixo semi-major 384.748 km (239.071 mi) Distância média de 385 mil km (239 mil mi ) Paralaxe sine inversa 384.400 km (238.900 mi ) Perigee ( ou seja, min. distância da Terra ) 362.600 km (225.300 mi)',
#      'qas': [{'id': 0,
#        'question': 'Quanto tempo leva para a Lua dar a volta à Terra',
#        'answers': [{'answer_start': 0, 'text': None}]}]}]},
#   {'title': 'Primeiro-ministro da Maurícia',
#    'paragraphs': [{'context': 'O primeiro-ministro de Maurício Brasão de armas de Maurício Bandeira de Maurício Incumbente Pravind Jugnauth desde 23 de janeiro de 2017 Estilo A Residência Honrosa Clarisse House (Oficial) Nomeador O presidente que deve nomear o deputado que apoia uma maioria clara na Assembleia Nacional Apeenah Gurib Aptointer Duração do mandato O prazer do presidente que serve desde que o titular do cargo tenha uma maioria na Assembleia Nacional A',
#      'qas': [{'id': 0,
#        'question': 'Primeiro-ministro da República de Mauritius',
#        'answers': [{'answer_start': 0, 'text': 'Pravind Jugnauth'}]}]}]},
#   {'title': '2018 FA Cup final',
#    'paragraphs': [{'context': 'A final da FA Cup de 2018 foi a partida final da 2017 -- 18 FA Cup e a 137a final da FA Cup, a competição de Copas de futebol mais antiga do mundo. Foi disputada no Wembley Stadium, em Londres, Inglaterra, em 19 de maio de 2018 entre o Manchester United e o Chelsea. Foi a segunda final consecutiva para o Chelsea após sua derrota pelo Arsenal no ano anterior .',
#      'qas': [{'id': 0,
#        'question': 'o que as equipes estão na final da fa cup',
#        'answers': [{'answer_start': 0, 'text': 'Manchester United'}]}]}]},
#   {'title': 'Sonho de uma noite de verão',
#    'paragraphs': [{'context': 'A peça consiste em quatro parcelas interligadas, ligadas por uma celebração do casamento do duque Teseu de Atenas e da rainha amazônica, Hippolyta, que se passa simultaneamente na floresta e no reino de Fairyland, sob a luz da lua.',
#      'qas': [{'id': 0,
#        'question': 'Onde está o conjunto de sonhos de uma noite de verão',
#        'answers': [{'answer_start': 0,
#          'text': 'na floresta e no reino de Fairyland'}]}]}]},
#   {'title': 'Lista de episódios de Black Sails',
#    'paragraphs': [{'context': "Black Sails é uma série de drama de televisão americana criada por Jon Steinberg e Robert Levine para Starz que estreou em 25 de janeiro de 2014 . É produzido pela Film Afrika Worldwide e Platinum Dunes . É escrito como um prequel para o romance Treasure Island de Robert Louis Stevenson . A série foi renovada para uma quarta temporada em 31 de julho de 2015 , antes da terceira temporada ter estreado '. Em 20 de julho de 2016, a quarta temporada de Starz",
#      'qas': [{'id': 0,
#        'question': 'Quando começa a nova série de velas pretas',
#        'answers': [{'answer_start': 0, 'text': None}]}]}]},
#   {'title': 'Neil Armstrong',
#    'paragraphs': [{'context': 'Neil Alden Armstrong (5 de agosto de 1930 - 25 de agosto de 2012) foi um astronauta americano e engenheiro aeronáutico que foi a primeira pessoa a andar na Lua . Ele também foi um aviador naval , piloto de teste e professor universitário .',
#      'qas': [{'id': 0,
#        'question': 'Quem foi a primeira pessoa que foi à Lua',
#        'answers': [{'answer_start': 0, 'text': 'Neil Alden Armstrong'}]}]}]},
#   {'title': 'Lista de filmes Lego e séries de TV',
#    'paragraphs': [{'context': 'Ano Título Estúdio de produção (s) Notas 2014 O Lego Movie Warner Animation Group Lançado 2017 O Lego Batman Filme Lançado O Lego Ninjago Filme Lançado 2019 A sequência de filmes Lego Em desenvolvimento The Billion Brick Race',
#      'qas': [{'id': 0,
#        'question': 'Quando saiu o primeiro filme de Lego',
#        'answers': [{'answer_start': 0, 'text': 'O filme Lego'}]}]}]},
#   {'title': 'Metal',
#    'paragraphs': [{'context': 'Os átomos de substâncias metálicas são tipicamente dispostos em uma das três estruturas cristalinas comuns, ou seja, corpo - centrado cúbico ( bcc ) , face - centrado cúbico ( fcc ) , e hexagonal perto - embalado ( hcp ) . Em bcc , cada átomo é posicionado no centro de um cubo de oito outros . Em fcc e hcp , cada átomo é cercado por doze outros , mas as diferentes estruturas de empilhamento.',
#      'qas': [{'id': 0,
#        'question': 'São metais puros feitos de átomos ou íons',
#        'answers': [{'answer_start': 0, 'text': 'átomos'}]}]}]},
#   {'title': 'Lista de canções em Victorious',
#    'paragraphs': [{'context': "Episode Title Performed by Single Season Soundtrack  Piloto ''  Make It Shine '' Tori Vega Yes Victorious  The Birthweek Song ''  You're the Reason '' Tori Vega Yes Victorious  Jade Dumps Beck ''  Chicago '' Trina Vega No N / A  Tori the Zombie ''  Finalmente Falling '' Tori Vega e Beck Oliver Yes Victorious  Survival of the Hottest ''",
#      'qas': [{'id': 0,
#        'question': 'que episódio em vitorioso é desistir',
#        'answers': [{'answer_start': 0, 'text': 'Freak o Freak Fora'}]}]}]},
#   {'title': 'Transporte ativo',
#    'paragraphs': [{'context': 'O transporte ativo é o movimento de moléculas através de uma membrana de uma região de sua menor concentração para uma região de sua maior concentração - na direção contra o gradiente de concentração. O transporte ativo requer energia celular para alcançar esse movimento. Existem dois tipos de transporte ativo - transporte ativo primário que usa ATP e transporte ativo secundário que usa um gradiente eletroquímico. Um exemplo de transpor ativo',
#      'qas': [{'id': 0,
#        'question': 'movimento de moléculas através de uma membrana alimentada por atp',
#        'answers': [{'answer_start': 0,
#          'text': 'Transporte ativo primário'}]}]}]},
#   {'title': 'Peter Minuit',
#    'paragraphs': [{'context': 'Minuit é creditado com a compra da ilha de Manhattan dos nativos americanos em troca de bens negociados avaliados em 60 florins . De acordo com o escritor Nathaniel Benchley , Minuit realizou a transação com Seyseys , chefe dos Canarsees , que estavam muito felizes em aceitar mercadorias valiosas em troca de uma ilha que era principalmente controlada pelos Weckquaesgeeks .',
#      'qas': [{'id': 0,
#        'question': 'que vendeu manhattan para os holandeses em 1626',
#        'answers': [{'answer_start': 0,
#          'text': 'Seyseys, chefe dos Canarsees'}]}]}]},
#   {'title': 'Cidade das Estrelas',
#    'paragraphs': [{'context': "(A canção ) começou no piano comigo apenas trabalhando em demos para Damien , enviando-lhe ideias até que algo realmente provocou . É tão engraçado que e  Audition '' são as duas músicas que as pessoas parecem estar respondendo ao mais , pelo menos até agora , porque eles tinham processos semelhantes no sentido de que eles tinham provavelmente a menor quantidade de confusão emocional no palco de demonstração de piano . ( ...)",
#      'qas': [{'id': 0,
#        'question': 'cidade das estrelas você está brilhando apenas para mim significando',
#        'answers': [{'answer_start': 0, 'text': None}]}]}]},
#   {'title': 'Tinta Master',
#    'paragraphs': [{'context': "Vencedor Vencedor do Terceiro Lugar Prêmios Primeiro Exibido ltimo Exibido Juízes ( ordem de cadeira ) 10 Shane O'Neill Tommy Helm James Vaughn Título de Tinta Master $ 100.000 Característica na revista Inked 17 de janeiro de 2012 6 de março de 2012 Oliver Peck Dave Navarro Chris Nuez 16 Steve Tefft Sarah Miller Sebastian Murphy 9 de outubro de 2012 18 de dezembro de 2012 16 Joey Hamilton Jime Litwa",
#      'qas': [{'id': 0,
#        'question': 'Quem foram os vencedores do Ink Master',
#        'answers': [{'answer_start': 0, 'text': None}]}]}]},
#   {'title': 'Deuces ( filme )',
#    'paragraphs': [{'context': 'Deuces é um drama de crime americano escrito e dirigido por Jamal Hill . O filme é estrelado por Larenz Tate , Meagan Good , Lance Gross e Siya . O filme é produzido pela Queen Latifah para sua produtora Flavor Unit Entertainment . Deuces estreou na Netflix em 1 de abril de 2017 .',
#      'qas': [{'id': 0,
#        'question': 'Em que ano saiu o filme deuces',
#        'answers': [{'answer_start': 0, 'text': '2017'}]}]}]},
#   {'title': 'Ministério dos Assuntos da Juventude e do Desporto',
#    'paragraphs': [{'context': 'O Ministério dos Assuntos da Juventude e Esportes , um ramo do Governo da ndia , que administra o Departamento de Assuntos da Juventude e o Departamento de Esportes na ndia . O ministério também ignora a organização dos jogos da Commonwealth 2010. A partir de julho de 2016, o Ministro dos Assuntos da Juventude e Esportes é o Ministro de Estado ( Carga Independente ) Rajyavardhan Singh Rathore',
#      'qas': [{'id': 0,
#        'question': 'que é o atual ministro do esporte da ndia',
#        'answers': [{'answer_start': 0,
#          'text': 'Rajyavardhan Singh Rathore'}]}]}]},
#   {'title': 'Lista da maioria - seguido contas do Instagram',
#    'paragraphs': [{'context': 'Rank Chg Nome da conta Proprietário Seguidores ( milhões ) Profissão País 1 .  instagram Instagram 235 Plataforma de mídia social EUA 2 .  selenagomez Selena Gomez 137 Músico e atriz EUA 3 .  cristiano Cristiano Ronaldo 126 Futebolista POR 4 .  arianagrande Ariana Grande 119 Músico e atriz EUA 5 .  beyonce Beyoncé 115 Músico e atriz EUA 6 .',
#      'qas': [{'id': 0,
#        'question': 'quem tem mais seguidores no instagram no mundo',
#        'answers': [{'answer_start': 0, 'text': 'Instagram'}]}]}]},
#   {'title': 'Vida ou algo parecido',
#    'paragraphs': [{'context': 'A maioria do filme foi filmado no local em Seattle , Washington, embora porções foram filmados no centro de Vancouver . A estação de TV no filme , KQMO , era realmente real - vida Seattle TV estação KOMO - TV ( o logotipo KOMO foi alterado no conjunto de KOMO 4 News e em vários veículos de notícias da KOMO , além de algumas bandeiras de microfone ) .',
#      'qas': [{'id': 0,
#        'question': 'onde estava a vida ou algo assim filmado',
#        'answers': [{'answer_start': 0, 'text': 'Seattle, Washington'}]}]}]},
#   {'title': 'Polícia Karnataka',
#    'paragraphs': [{'context': 'O Director-Geral e Inspector-Geral da Polícia ( DG&IGP ) é o chefe do departamento de polícia do Estado , e sob ele são Directores-Gerais Adicionais da Polícia . Cada Director-Geral da Polícia é responsável por uma função específica : lei e ordem , crime e serviços técnicos , administração , inteligência , a Polícia de Reserva do Estado de Karnataka , recrutamento e formação .',
#      'qas': [{'id': 0,
#        'question': 'o posto mais alto no departamento de polícia do estado de karnataka é',
#        'answers': [{'answer_start': 0,
#          'text': 'O Director-Geral e Inspector-Geral da Polícia ( DG&IGP )'}]}]}]},
#   {'title': 'Feriados na Espanha',
#    'paragraphs': [{'context': 'Nome nativo Janeiro 1 Dia de Ano Novo ( Feriado nacional ) Ação Nuevo Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y Y 28 de fevereiro Feriado regional Día de Yalucí',
#      'qas': [{'id': 0,
#        'question': 'é um feriado bancário hoje em Espanha',
#        'answers': [{'answer_start': 0, 'text': None}]}]}]},
#   {'title': 'Albert Popwell',
#    'paragraphs': [{'context': 'Dirty Harry ( 1971 ) - Bank Robber ( não creditado )',
#      'qas': [{'id': 0,
#        'question': 'quem jogou o ladrão de banco em harry sujo',
#        'answers': [{'answer_start': 0, 'text': None}]}]}]},
#   {'title': 'Lista de organizações mais ricas',
#    'paragraphs': [{'context': 'Igreja Católica $ 140 bilhões + Vaticano A Igreja de Jesus Cristo dos ltimos Dias Santos $ 67 bilhões + Igreja dos Estados Unidos da Inglaterra $ 7,8 bilhões Reino Unido Opus Dei ( parte da Igreja Católica ) $ 2,8 bilhões Itália Igreja de Scientology $ 2,0 bilhões Estados Unidos',
#      'qas': [{'id': 0,
#        'question': 'Qual é o valor da Igreja Católica',
#        'answers': [{'answer_start': 0, 'text': '$140 bilhões +'}]}]}]},
#   {'title': 'região Black Dirt',
#    'paragraphs': [{'context': 'A região de Black Dirt leva o nome do solo escuro e extremamente fértil que sobrou de um antigo fundo de lago glacial aumentado por décadas de inundações passadas do rio Wallkill. O 26.000 acres (10.400 ha) de lama restante é a maior concentração de tal solo nos Estados Unidos fora do Everglades da Flórida.',
#      'qas': [{'id': 0,
#        'question': 'onde é o melhor solo agrícola nos EUA e de onde veio toda a sujeira',
#        'answers': [{'answer_start': 0,
#          'text': 'A região da sujeira negra'}]}]}]},
#   {'title': 'Tabla',
#    'paragraphs': [{'context': "O tabla consiste em dois tambores pequenos de tamanho e formas ligeiramente diferentes: daya também chamado dahina significado à direita (também chamado  tabla '' ) , e baya também chamado bahina significado à esquerda (também chamado  dagga '' ) . O tabla bit daya é tocado pela mão direita do músico (mão dominante) , e é de cerca de 25 centímetros (também chamado de ) .",
#      'qas': [{'id': 0,
#        'question': 'o par de tambores de mão usados na música clássica indiana é chamado',
#        'answers': [{'answer_start': 0, 'text': 'tabla'}]}]}]},
#   {'title': 'Suboficial',
#    'paragraphs': [{'context': 'O moderno oficial mesquinho remonta à Era da Vela . Oficiais mesquinhos classificam entre oficiais navais (tanto comissionados quanto mandado) e marinheiros mais alistados . Estes eram homens com alguma reivindicação de posto de oficial , o suficiente para distingui-los das classificações comuns , sem elevá-los tão alto quanto os oficiais do mar . Vários eram oficiais de mandado , no sentido literal de serem nomeados por mandado , e como os oficiais do mar de mandado , seus superiores , o',
#      'qas': [{'id': 0,
#        'question': 'De onde vem o termo oficial mesquinho?',
#        'answers': [{'answer_start': 0, 'text': 'A Era da Vela'}]}]}]},
#   {'title': 'Símbolos olímpicos',
#    'paragraphs': [{'context': "Os anéis são cinco anéis interligados , azul colorido , amarelo , preto , verde e vermelho em um campo branco , conhecido como os  anéis olímpicos '' . O símbolo foi originalmente projetado em 1912 por de Coubertin . Ele parece ter pretendido que os anéis representassem as cinco regiões participantes: África , Ásia , América , Oceania e Europa . De acordo com Coubertin , as cores dos anéis juntos",
#      'qas': [{'id': 0,
#        'question': 'O que significam as cores dos anéis olímpicos',
#        'answers': [{'answer_start': 0, 'text': None}]}]}]},
#   {'title': 'Israel',
#    'paragraphs': [{'context': 'Israel ( / zrel / ; Hebraico :  , árabe :  ) , oficialmente o Estado de Israel ( hebraico :   , árabe :   ) , é um país no Oriente Médio , na costa sudeste do Mar Mediterrâneo e na costa norte do Mar Vermelho . Tem fronteiras terrestres com o Líbano ao norte , a Síria ao nordeste da Faixa de Gaza Palestina e ao nordeste da Faixa de Gaza',
#      'qas': [{'id': 0,
#        'question': 'onde está Israel localizado no mapa do mundo',
#        'answers': [{'answer_start': 0,
#          'text': 'no Oriente Médio, na costa sudeste do Mar Mediterrâneo e na costa norte do Mar Vermelho'}]}]}]},
#   {'title': 'Tinker Tailor Soldier Spy ( filme )',
#    'paragraphs': [{'context': "Tinker Tailor Soldier Spy é um filme de espionagem da Guerra Fria de 2011 dirigido por Tomas Alfredson . O roteiro foi escrito por Bridget O'Connor e Peter Straughan , baseado no romance de 1974 de John le Carré com o mesmo nome . O filme, estrelado por Gary Oldman como George Smiley , juntamente com Colin Firth , Tom Hardy , John Hurt , Toby Jones , Mark Strong , e Benedict Cumber",
#      'qas': [{'id': 0,
#        'question': 'quem jogou smiley em tinker alfaiate soldado espião',
#        'answers': [{'answer_start': 0, 'text': 'Gary Oldman'}]}]}]},
#   {'title': 'Micrômetro',
#    'paragraphs': [{'context': 'Os micrômetros de tubo têm uma bigorna cilíndrica posicionada perpendicularmente a um fuso e é usada para medir a espessura dos tubos.',
#      'qas': [{'id': 0,
#        'question': 'é o medidor de parafuso do micrômetro usado para a medição do diâmetro interno do tubo',
#        'answers': [{'answer_start': 0, 'text': None}]}]}]},
#   {'title': "Temperança  Ossos '' Brennan",
#    'paragraphs': [{'context': "Brennan é melhor amiga de sua colega de trabalho, Angela, dizendo na estréia da 6a temporada que ela ama Angela  como uma irmã '' e vai ser uma tia de Hodgins 'e o filho recém-nascido de Angela . É revelado no final do final da 6a temporada  The Change in the Game '' que Brennan está grávida e o pai é Booth .",
#      'qas': [{'id': 0,
#        'question': 'Quando Brennan engravida pela primeira vez',
#        'answers': [{'answer_start': 0, 'text': 'sexta temporada finale'}]}]}]},
#   {'title': "The Handmaid's Tale (série de televisão)",
#    'paragraphs': [{'context': 'Temporada Episodes Lançado originalmente Lançado pela primeira vez em 26 de abril de 2017 ( 2017 - 04 - 26 ) 14 de junho de 2017 ( 2017 - 06 - 14 ) 13 de abril de 25 , 2018 ( 2018 - 04 - 25 ) 11 de julho de 2018 ( 2018 - 07 - 11 )',
#      'qas': [{'id': 0,
#        'question': 'Quando começou a segunda temporada do conto da serva',
#        'answers': [{'answer_start': 0, 'text': '25 de abril de 2018'}]}]}]},
#   {'title': 'Zona morta ( ecologia )',
#    'paragraphs': [{'context': 'Zonas mortas são áreas hipóxicas (baixa - oxigênio) nos oceanos do mundo e grandes lagos , causadas por  poluição excessiva de nutrientes de atividades humanas, juntamente com outros fatores que esgotam o oxigênio necessário para suportar a maior parte da vida marinha no fundo e perto - água. ( NOAA ) . Na década de 1970 oceanógrafos começaram a notar o aumento dos casos de zonas mortas. Estes ocorrem perto de costas habitadas , onde a vida aquática é mais concentrada (.',
#      'qas': [{'id': 0,
#        'question': 'O que causa uma zona morta no oceano',
#        'answers': [{'answer_start': 0,
#          'text': 'poluição excessiva de nutrientes de atividades humanas, juntamente com outros fatores que esgotam o oxigênio'}]}]}]},
#   {'title': 'Alejandro García Padilla',
#    'paragraphs': [{'context': 'Alejandro Javier García Padilla (em espanhol: Alejandro Javier García Padilla; nascido em 3 de agosto de 1971) é um político e advogado porto-riquenho que serviu como o 11o governador de Porto Rico de 2013 a 2017. Antes desta posição , García Padilla ocupou vários papéis no cenário político de Porto Rico ; primeiro como Secretário de Assuntos do Consumidor e, em seguida, como membro do Senado.',
#      'qas': [{'id': 0,
#        'question': 'que é o atual governador de puerto rico',
#        'answers': [{'answer_start': 0,
#          'text': 'Alejandro Javier García Padilla'}]}]}]},
#   {'title': 'Junção neuromuscular',
#    'paragraphs': [{'context': 'Os músculos requerem inervação para funcionar - e até mesmo apenas para manter o tônus muscular , evitando atrofia . A transmissão sináptica na junção neuromuscular começa quando um potencial de ação atinge o terminal pré-sináptico de um neurônio motor , que ativa os canais de cálcio dependentes da tensão para permitir que os íons de cálcio entrem no neurônio . Os íons de cálcio se ligam às proteínas do sensor (sinaptotagmin) nas vesículas sinápticas.',
#      'qas': [{'id': 0,
#        'question': 'qual o efeito que a acetilcolina tem sobre o sarcolemma',
#        'answers': [{'answer_start': 0,
#          'text': 'pode despolarizar a fibra muscular, causando uma cascata que eventualmente resulta em contração muscular'}]}]}]},
#   {'title': 'Claire Underwood',
#    'paragraphs': [{'context': "Claire Hale Underwood é originalmente do enclave exclusivo Highland Park de Dallas, Texas . Seu falecido pai era um grande republicano do Texas. Enquanto estava no Radcliffe College em Cambridge , ela conheceu Francis J. Underwood , um estudante de Direito de Harvard da Carolina do Sul . Ela é de uma família rica, e o show a caracteriza como um  Dallas Debutante '' e  Lily White '' . Ela conta que seu pai estava levando seu Kennedy Plaza 's.",
#      'qas': [{'id': 0,
#        'question': 'que joga a mãe de Claire Underwood na casa de cartas',
#        'answers': [{'answer_start': 0, 'text': 'Ellen Burstyn'}]}]}]},
#   {'title': '2017 Todos - Irlanda final do campeonato de futebol sénior',
#    'paragraphs': [{'context': 'Dublin venceu a final por um ponto em um placar de 1 - 17 para 1 - 16 para reivindicar seu terceiro título consecutivo , a primeira vez que isso aconteceu desde 1921 - 23 .',
#      'qas': [{'id': 0,
#        'question': 'que venceu a final de futebol da Irlanda 2017',
#        'answers': [{'answer_start': 0, 'text': 'Dublin'}]}]}]},
#   {'title': 'Meus Três Filhos',
#    'paragraphs': [{'context': 'Enquanto os três filhos sempre foram centrais para o enredo , várias mudanças importantes ocorreram no final dos anos 1960 . Na primavera de 1967 , as classificações para a série começaram a ceder e My Three Sons terminou sua sétima temporada em 31o lugar nas classificações Nielsen . Foi decidido que a temporada de 1967 - 1968 traria o programa não apenas um novo intervalo de tempo , mas também novos enredos para apimentar as classificações . No outono de 1967, meu filho mudou-se',
#      'qas': [{'id': 0,
#        'question': 'quem jogou robbie douglas esposa em meus três filhos',
#        'answers': [{'answer_start': 0, 'text': 'Tina Cole'}]}]}]},
#   {'title': 'Recordes da temporada regular da NBA',
#    'paragraphs': [{'context': '13 por Stephen Curry , Golden State Warriors ( vs. New Orleans Pelicans ) em 7 de novembro de 2016 (13 / 17 )',
#      'qas': [{'id': 0,
#        'question': 'que atingiu o maior número de 3 ponteiros em um jogo nba',
#        'answers': [{'answer_start': 0, 'text': '13'}]}]}]},
#   {'title': 'Título Torrens',
#    'paragraphs': [{'context': "O título de Torrens é um sistema de registo e transferência de terras , no qual um Estado cria e mantém um registo de explorações de terras , que serve como prova conclusiva ( denominado  indefasibilidade '' ) do título da pessoa registada no registo como proprietário ( proprietário ) , e de todos os outros interesses registados no registo . Os interesses que não são garantidos são chamados  interesses primordiais '' .",
#      'qas': [{'id': 0,
#        'question': 'o sistema mais comum de título de terra na Austrália',
#        'answers': [{'answer_start': 0, 'text': 'Título Torrens'}]}]}]},
#   {'title': 'A Carga - Fora',
#    'paragraphs': [{'context': "The Load - Out '' descreve as práticas diárias de uma banda e sua equipe de estrada em uma turnê de concerto , e as emoções evocadas ao longo de tal empreendimento . Os três primeiros versos da música consistem em Browne cantando e tocando piano com David Lindley tocando guitarra de aço . Eles são mais tarde acompanhados por um sintetizador , seguido pelo resto da banda . Eventualmente  The Load - Out '' segue em uma interpretação de Maurice Williams ' 1960 sol ' hit",
#      'qas': [{'id': 0,
#        'question': 'que canta com jackson marrom na carga para fora',
#        'answers': [{'answer_start': 0, 'text': 'Rosemary Butler'}]}]}]},
#   {'title': 'Lista de registros internacionais do Twenty20',
#    'paragraphs': [{'context': 'Runs Bowling figures Bowler Bowling team Oposição Local Data Scorecard 69 4 -- 0 -- 69 -- 0 Barry McCarthy Irlanda Afeganistão Greater Noida 12 Março 2017 Scorecard 68 4 -- 0 -- 68 -- 1 Kyle Abbott África do Sul West Indies Joanesburgo 11 Janeiro 2015 Scorecard 64 4 -- 0 -- 64 -- 1 James Anderson Inglaterra Austrália Sydney 9 Janeiro 2007 Scorecard 64 4 ---- 64 -- 0 Sanath J',
#      'qas': [{'id': 0,
#        'question': 'quem marcou mais corridas em entradas internacionais t20',
#        'answers': [{'answer_start': 0, 'text': None}]}]}]},
#   {'title': 'Derek Shepherd',
#    'paragraphs': [{'context': 'Na 11a temporada , Derek está envolvido em um acidente de carro fatal enquanto dirige para o aeroporto para sua viagem final a Washington . Ele é capaz de ouvir e processar a entrada auditiva , mas incapaz de falar . Ele é reconhecido por Winnie , uma das vítimas de um acidente que ele ajudou no início , que diz aos cirurgiões que o nome do paciente é Derek e que ele é um cirurgião também . O hospital em que ele foi levado para a cabeça não foi detectado rapidamente.',
#      'qas': [{'id': 0,
#        'question': "O que acontece com o Dr. Shepherd em Grey's",
#        'answers': [{'answer_start': 0,
#          'text': 'Acidente de carro fatal'}]}]}]},
#   {'title': 'The 100 (série de novelas)',
#    'paragraphs': [{'context': 'The 100 é uma série de romances de ficção científica para jovens adultos de Kass Morgan . O primeiro livro da série, The 100 , foi publicado em 3 de setembro de 2013 , por Little , Brown Books for Young Readers . Dia 21 , sua sequência , foi lançado em 25 de setembro de 2014 , e Homecoming foi lançado em 26 de fevereiro de 2015 . Um quarto romance, Rebellion , foi lançado em 6 de dezembro de 2016.',
#      'qas': [{'id': 0,
#        'question': 'Quando sai o livro 2 dos 100',
#        'answers': [{'answer_start': 0,
#          'text': 'em 25 de setembro de 2014'}]}]}]},
#   {'title': 'Nissan Armada',
#    'paragraphs': [{'context': 'Em 10 de fevereiro de 2016, a Nissan revelou a segunda geração Armada no Chicago Auto Show , e entrou à venda em agosto de 2016 como um modelo 2017. Esta versão é baseada na Nissan Patrol e Infiniti QX80 , e é montado no Japão , exceto para o Endurance V8 motor , que é montado em Decherd , Tennessee . A Armada cresceu em comprimento e largura , mas a distância entre eixos moderadamente reduzida.',
#      'qas': [{'id': 0,
#        'question': 'Quando a nissan armada mudou o estilo corporal',
#        'answers': [{'answer_start': 0, 'text': '2016'}]}]}]},
#   {'title': 'Síndrome de Down',
#    'paragraphs': [{'context': 'A síndrome de Down é uma das anormalidades cromossômicas mais comuns em humanos. Ocorre em cerca de um por 1000 bebês nascidos a cada ano. Em 2015 , a síndrome de Down estava presente em 5,4 milhões de indivíduos e resultou em 27.000 mortes por 43.000 mortes em 1990 . É nomeado após John Langdon Down , o médico britânico que descreveu totalmente a síndrome em 1866. Alguns aspectos da condição foram descritos anteriormente por Jean - Étienne Dominique Esquirol 18',
#      'qas': [{'id': 0,
#        'question': 'de onde vem a síndrome do nome para baixo',
#        'answers': [{'answer_start': 0,
#          'text': 'John Langdon Down, o médico britânico que descreveu completamente a síndrome em 1866.'}]}]}]},
#   {'title': 'Listra de sangue',
# ...
#      'qas': [{'id': 0,
#        'question': 'Que idade você pode se casar em Itália',
#        'answers': [{'answer_start': 0,
#          'text': '16 com o consentimento do tribunal'}]}]}]},
#   {'title': 'marca-passo cardíaco',
#    'paragraphs': [{'context': 'A contração do músculo cardíaco (músculo cardíaco) em todos os animais é iniciada por impulsos elétricos conhecidos como potenciais de ação. A taxa na qual esses impulsos de fogo controla a taxa de contração cardíaca, ou seja, a freqência cardíaca. As células que criam esses impulsos rítmicos, estabelecendo o ritmo para bombeamento de sangue, são chamadas de células marcapasso, e controlam diretamente a freqência cardíaca. Eles compõem o marcapasso cardíaco, isto é natural ,',
#      'qas': [{'id': 0,
#        'question': 'onde está localizado o marca-passo natural do coração',
#        'answers': [{'answer_start': 0, 'text': 'nó sinoatrial ( SA )'}]}]}]},
#   {'title': 'Lista de episódios de Arrow',
#    'paragraphs': [{'context': 'Temporada Episódios Originalmente exibido Nielsen audiências Primeiro exibido ltima exibição Classificação Média espectadores ( em milhões ) 23 10 de outubro de 2012 ( 2012 - 10 ) 15 de maio de 2013 ( 2013 - 05 - 15 ) 130 3.68 23 9 de outubro de 2013 ( 2013 - 10 - 09 ) 14 de maio de 2014 ( 2014 - 05 - 14 ) 128 05 3,28 23 de outubro de 8 de 2015 ( 2014 - 10 08 )',
#      'qas': [{'id': 0,
#        'question': 'Quantos episódios estão na sexta temporada de Arrow?',
#        'answers': [{'answer_start': 0, 'text': '23'}]}]}]},
#   {'title': 'Monte Rainier',
#    'paragraphs': [{'context': 'Monte Rainier Monte Tacoma ( Lushootseed ) Monte Rainier como visto a partir do nordeste . Ponto mais alto Elevação 14,411 pés (4,392 m) NAVD88 Proeminência 13.210 pés (4,026 m) Isolação 731 mi (1,176 km ) Listando Picos mais proeminentes do mundo 21o picos proeminentes da América do Norte 4o picos mais altos da América do Norte 7o picos maiores dos EUA 17o pico maior pico maior do vulcão',
#      'qas': [{'id': 0,
#        'question': 'quando foi a última vez que o monte mais chuvoso entrou em erupção',
#        'answers': [{'answer_start': 0,
#          'text': 'Novembro a Dezembro de 1894'}]}]}]},
#   {'title': 'Batman v Superman: A Origem da Justiça',
#    'paragraphs': [{'context': 'Luthor executa seu plano de backup, desencadeando um monstro geneticamente modificado com DNA do corpo de Zod e seu próprio sangue. Diana Prince chega inesperadamente; revelando sua natureza meta-humana, ela une forças com Batman e Superman para eliminar a criatura. Quando eles estão todos superados, Superman percebe sua vulnerabilidade à kryptonita, e recupera a lança para matá-la. Nos últimos momentos da criatura, Superman mata.',
#      'qas': [{'id': 0,
#        'question': 'quem faz lex luthor criado em batman vs superman',
#        'answers': [{'answer_start': 0,
#          'text': 'Um monstro geneticamente modificado com DNA do corpo de Zod e seu próprio sangue'}]}]}]},
#   {'title': 'História dos EUA de idade mínima de compra de álcool por estado',
#    'paragraphs': [{'context': 'Estado Pré-Proibição (antes de 1919 ) Pós-Proibição ( depois de 1933 ) 1970s / 26a Emenda ( adotada em 1971 ) 1980s / Lei da Idade do Consumo de 1984 Alabama Pré 1881 : Nenhum 1881 : 21 ( nenhum com consentimento dos pais ) 21 1975 : Baixo para 19 1986 : Elevado para 21 21 (ninguém menor de idade é permitido consumo Seção 28 - 1 1970)',
#      'qas': [{'id': 0,
#        'question': 'quando a idade de beber mudou para 21 em conecticut',
#        'answers': [{'answer_start': 0, 'text': '1985'}]}]}]},
#   {'title': '2018 Colégio de futebol Playoff campeonato nacional',
#    'paragraphs': [{'context': "2018 College Football Playoff National Championship foi um jogo de futebol universitário que determinou o campeão nacional na NCAA Division I Football Bowl Subdivision para a temporada 2017. O Alabama Crimson Tide derrotou o Georgia Bulldogs 26 -- 23 em horas extras. Alabama superou um déficit de 13 -- 0 no intervalo. Tua Tagovailoa e Da'Ron Payne foram respectivamente nomeados os jogadores ofensivos e defensivos do jogo. O",
#      'qas': [{'id': 0,
#        'question': 'Quem vai estar no campeonato universitário',
#        'answers': [{'answer_start': 0, 'text': 'Tide derrotou o'}]}]}]},
#   {'title': 'Tratado de Paris (1898)',
#    'paragraphs': [{'context': 'O Tratado de Paris de 1898 foi um acordo feito em 1898 que envolveu a Espanha renunciando a quase todo o Império Espanhol restante , especialmente Cuba , e cedendo Porto Rico , Guam , e as Filipinas para os Estados Unidos . A cessão das Filipinas envolveu um pagamento de US $ 20 milhões dos Estados Unidos para a Espanha . O tratado foi assinado em 10 de dezembro de 1898 , e terminou a Guerra Hispano-Americana . O Tratado de Paris entrou em vigor em 10 de dezembro de 1898 .',
#      'qas': [{'id': 0,
#        'question': 'o que a posse espanhola fez os Estados Unidos comprar sob o tratado de paris',
#        'answers': [{'answer_start': 0, 'text': None}]}]}]},
#   {'title': 'Bryan Cranston',
#    'paragraphs': [{'context': 'Bryan Lee Cranston (nascido em 7 de março de 1956) é um ator americano , dublador , produtor , diretor e roteirista . Ele é mais conhecido por retratar Walter White na série de drama criminal da AMC Breaking Bad , Hal na série de comédia da Fox Malcolm in the Middle , e Dr. Tim Whatley na série de comédia da NBC Seinfeld .',
#      'qas': [{'id': 0,
#        'question': 'que jogou hal em malcolm no meio',
#        'answers': [{'answer_start': 0, 'text': 'Bryan Lee Cranston'}]}]}]},
#   {'title': 'Richard Keith ( ator )',
#    'paragraphs': [{'context': "Keith Thibodeaux (nascido em 1 de dezembro de 1950) é um ex-ator infantil americano de televisão e cinema e músico , mais conhecido por interpretar Little Ricky na sitcom de televisão I Love Lucy e The Lucy - Desi Comedy Hour , seu sobrenome  Thibodeaux '' que era francês Cajun foi alterado pela co-estrela Desi Arnaz , para  Keith '' porque seu sobrenome foi mais difícil de pronunciar Lucy.",
#      'qas': [{'id': 0,
#        'question': 'quem foi a criança que jogou pouco ricky em eu amo lucy',
#        'answers': [{'answer_start': 0, 'text': 'Keith Thibodeaux'}]}]}]},
#   {'title': 'Segunda Guerra Mundial',
#    'paragraphs': [{'context': 'O Império do Japão tinha como objetivo dominar a Ásia e o Pacífico e já estava em guerra com a República da China em 1937, mas a guerra mundial é geralmente dito ter começado em 1 de setembro de 1939 com a invasão da Polônia pela Alemanha nazista e subsequentes declarações de guerra contra a Alemanha pela França e o Reino Unido.',
#      'qas': [{'id': 0,
#        'question': 'Quando a Segunda Guerra Mundial começou na Ásia',
#        'answers': [{'answer_start': 0, 'text': '1 de setembro de 1939'}]}]}]},
#   {'title': 'Os Beatles',
#    'paragraphs': [{'context': 'Os Beatles foram uma banda de rock inglesa formada em Liverpool em 1960. Com membros John Lennon , Paul McCartney , George Harrison e Ringo Starr , eles se tornaram amplamente considerados como o ato mais importante e mais influente da era do rock . Enraizada em skiffle , batida e rock and roll dos anos 1950 , os Beatles mais tarde experimentaram vários estilos musicais, variando de baladas pop e música indiana para psicodelia e hard rock , muitas vezes incorporando elementos clássicos',
#      'qas': [{'id': 0,
#        'question': 'Quais são os nomes dos membros dos beatles',
#        'answers': [{'answer_start': 0, 'text': None}]}]}]},
#   {'title': 'Espírito no céu',
#    'paragraphs': [{'context': "Spirit in the Sky '' é uma canção escrita e originalmente gravada por Norman Greenbaum e lançada no final de 1969. O single tornou-se um disco de ouro, vendendo dois milhões de cópias de 1969 a 1970 e alcançou o número três na parada Billboard Hot 100 dos EUA (18 de abril de 1970), onde durou 15 semanas no Top 100. A Billboard classificou o registro como a música número 22 de 1970. Também subiu para o número um nas paradas do Reino Unido e do Canadá.",
#      'qas': [{'id': 0,
#        'question': 'que faz o espírito da canção no céu',
#        'answers': [{'answer_start': 0, 'text': 'Norman Greenbaum'}]}]}]},
#   {'title': 'Hamlet',
#    'paragraphs': [{'context': 'Hamlet brinca com Cláudio sobre onde ele escondeu o corpo de Polônio, e o rei, temendo por sua vida, envia Rosencrantz e Guildenstern para acompanhar Hamlet para a Inglaterra com uma carta selada ao rei inglês pedindo que Hamlet seja executado imediatamente.',
#      'qas': [{'id': 0,
#        'question': 'que é designado para levar aldeia para a Inglaterra',
#        'answers': [{'answer_start': 0, 'text': 'Rosencrantz'}]}]}]},
#   {'title': 'Dora o Explorador',
#    'paragraphs': [{'context': 'A série gira em torno de Dora , uma menina americana de 7 anos de idade de herança indígena mexicana , com um amor de embarcar em missões relacionadas a uma atividade que ela quer participar ou um lugar que ela quer ir , acompanhada por sua mochila roxa falante e companheiro macaco antropomórfico chamado Botas (nomeado por seu amado par de botas vermelhas ) . Cada episódio é baseado em torno de uma série de eventos cíclicos que ocorrem ao longo do caminho Dor',
#      'qas': [{'id': 0,
#        'question': 'que tipo de animal é botas de dora',
#        'answers': [{'answer_start': 0, 'text': 'macaco antropomórfico'}]}]}]},
#   {'title': 'NFL no Dia de Ação de Graças',
#    'paragraphs': [{'context': 'Season Visiting Team Score Home Team Score OT 23 de novembro de 2006 Miami Dolphins 27 Detroit Lions 10 Tampa Bay Buccaneers 10 Dallas Cowboys 38 Denver Broncos 10 Kansas City Chiefs 19 de novembro de 22, 2007 Green Bay Packers 37 Detroit Lions 26 New York Jets Dallas Cowboys 34 Indianapolis Colts 31 Atlanta Falcons 13 de novembro de 27, 2008 Tennessee Titans 47 Detroit Lions 10',
#      'qas': [{'id': 0,
#        'question': 'quando foi a última vez que os leões destroit perderam em ação de graças',
#        'answers': [{'answer_start': 0, 'text': '24 de novembro de 2016'}]}]}]},
#   {'title': 'Dia da República ( ndia )',
#    'paragraphs': [{'context': 'A principal celebração do Dia da República é realizada na capital nacional, Nova Délhi, no Rajpath antes do presidente da ndia. Neste dia, desfiles cerimoniais ocorrem no Rajpath, que são realizados como um tributo à ndia; sua unidade na diversidade e rico patrimônio cultural.',
#      'qas': [{'id': 0,
#        'question': 'Onde é celebrado o Dia da República da ndia',
#        'answers': [{'answer_start': 0,
#          'text': 'na capital nacional, Nova Deli, no Rajpath antes do presidente da ndia'}]}]}]},
#   {'title': 'The Legend of Korra (jogo eletrônico)',
#    'paragraphs': [{'context': "O jogo leva cerca de quatro a seis horas para jogar , mas contém  um novo jogo + tipos '' . Estes incluem um corredor sem fim com Naga , e pró-dobrando partidas , onde equipes de três tentam dobrar um ao outro fora de uma arena . Este modo , que implementa as regras pró-dobramento descritas na série , está disponível depois de completar o jogo , com o jogador controlando o  Fire Fert Korre e sua equipe  Fire Ferret ''",
#      'qas': [{'id': 0,
#        'question': 'Quanto tempo é a lenda do jogo de korra',
#        'answers': [{'answer_start': 0,
#          'text': 'cerca de quatro a seis horas'}]}]}]},
#   {'title': 'Glomérulo ( rim )',
#    'paragraphs': [{'context': 'O glomérulo ( / lmr ( j ) l s , lo - / ) , glomérulo plural , é uma rede de capilares conhecida como um tufo , localizado no início de um néfron no rim . O tufo é estruturalmente apoiado por células mesangiais intraglomerulares . O sangue é filtrado através de suas paredes mesangiais intragulares .',
#      'qas': [{'id': 0,
#        'question': 'a qual parte do rim pertence o glomérulo',
#        'answers': [{'answer_start': 0,
#          'text': 'O início de um nefrônio'}]}]}]},
#   {'title': 'As Aventuras de Elmo em Grouchland',
#    'paragraphs': [{'context': 'Mandy Patinkin como Huxley',
#      'qas': [{'id': 0,
#        'question': 'quem interpreta o cara mau em elmo em grouchland',
#        'answers': [{'answer_start': 0, 'text': 'Mandy Patinkin'}]}]}]},
#   {'title': 'Placa epifisária',
#    'paragraphs': [{'context': 'A ossificação endocondral é responsável pelo desenvolvimento ósseo inicial da cartilagem no útero e em lactentes e pelo crescimento longitudinal de ossos longos na placa epifisária. Os condrócitos da placa estão sob constante divisão por mitose. Essas células filhas empilham de frente para a epífise, enquanto as células mais velhas são empurradas para a diafise.  medida que os condrócitos mais velhos degeneram, os novos osteoblastos se formam.',
#      'qas': [{'id': 0,
#        'question': 'onde o crescimento longitudinal ocorre em ossos longos',
#        'answers': [{'answer_start': 0, 'text': 'na placa epifisária'}]}]}]},
#   {'title': 'A Christmas Carol (filme de 1938)',
#    'paragraphs': [{'context': 'June Lockhart como Belinda Cratchit (não creditada)',
#      'qas': [{'id': 0,
#        'question': 'fez june lockhart jogar em um natal carol',
#        'answers': [{'answer_start': 0, 'text': None}]}]}]},
#   {'title': 'O Predador (filme)',
#    'paragraphs': [{'context': 'O filme é estrelado por Boyd Holbrook , Olivia Munn , Trevante Rhodes , Keegan - Michael Key , Sterling K. Brown , Jacob Tremblay , Yvonne Strahovski , Alfie Allen , e Thomas Jane . Ele completou as filmagens em junho de 2017 , e está programado para ser lançado em 14 de setembro de 2018 , pela 20th Century Fox em IMAX , 3D , bem como formatos padrão.',
#      'qas': [{'id': 0,
#        'question': 'Quando será lançado o novo filme de predador',
#        'answers': [{'answer_start': 0, 'text': '14 de setembro de 2018'}]}]}]},
#   {'title': 'Tom Payne ( ator )',
#    'paragraphs': [{'context': 'Thomas Payne (nascido em 21 de dezembro de 1982) é um ator inglês. Ele é mais conhecido por aparecer em The Walking Dead da AMC como Paul  Jesus Rovia .',
#      'qas': [{'id': 0,
#        'question': 'Quem é o ator que interpreta Jesus ao andar morto',
#        'answers': [{'answer_start': 0, 'text': 'Thomas Payne'}]}]}]},
#   {'title': 'Clube de futebol de Collingwood',
#    'paragraphs': [{'context': 'Em 2018 Collingwood fez as finais pela primeira vez desde 2013, terminando em terceiro lugar, atrás de West Coast e Richmond . Perder a segunda final de qualificação para West Coast , eles passaram a bater GWS e o reinante premiers Richmond para chegar a 2018 Grand Final , onde foram derrotados 79 - 74 pelo West Coast Eagles .',
#      'qas': [{'id': 0,
#        'question': 'quando foi a última vez que Collingwood jogou finais',
#        'answers': [{'answer_start': 0, 'text': '2013'}]}]}]},
#   {'title': 'Fox Mulder',
#    'paragraphs': [{'context': "Fox Mulder The X-Files personagem Primeira aparição  Piloto '' ( 10 de setembro de 1993 ) Retratado por David Duchovny City Washington , DC Informação Ocupação FBI Agente Especial Família O Homem Fumador ( pai biológico ) Teena Mulder ( mãe ) Bill Mulder ( pai legal ) Jeffrey Spender ( meio-irmão paterno ) Samantha Mulder ( meio-irmã materna ) William Scully ( filho ) Unborn Child Partners",
#      'qas': [{'id': 0,
#        'question': 'quem é o pai de mulder nos arquivos x',
#        'answers': [{'answer_start': 0, 'text': 'O Homem Fumador'}]}]}]},
#   {'title': 'Torta Whoopie',
#    'paragraphs': [{'context': 'Pensilvânia , Maine , Massachusetts , Virginia e New Hampshire todos afirmam ser o berço da torta de whoopie . O Pennsylvania Dutch Convention & Visitors Bureau observa que a receita de torta de whoopie vem da cultura alemã da área Amish e Pensilvânia - origens que são improváveis de deixar um rastro oficial de papel - e foi transmitida através de gerações . A padaria de Labadie em Lewiston, Maine, vem fazendo a confeitaria desde 1925.',
#      'qas': [{'id': 0,
#        'question': 'de onde veio o nome whoopie pie',
#        'answers': [{'answer_start': 0, 'text': None}]}]}]},
#   ...]}

# %%
json_data =squad
file_path = "data.json"
with open(file_path, "w") as json_file:
    json.dump(json_data, json_file, indent=4)

print(f"Variable saved as JSON")
# Out:
# Variable saved as JSON

# %%
import pandas as pd
import json

# Load the Excel spreadsheet
planilha = pd.read_excel('../../2. Seleção de modelos e dados/Modelo Opus/nq-traduzido-opus-5k.xlsx')

print("Primeira linha da planilha:")
print(planilha.iloc[0])

# Initialize the JSON structure
squad = {"data": []}

# Iterate over the rows of the spreadsheet
for idx, linha in planilha.iterrows():
    estrutura = {
        "title": str(linha['t']),  # Assuming there is a column named 't' for title
        "paragraphs": [
            {
                "context": str(linha['q']),  # Replace 'q' with the correct column name for the question
                "qas": [
                    {
                        "id": idx,
                        "question": str(linha['l']),  # Replace 's' with the correct column name for the answer
                        "answers": [
                            {
                                "answer_start": 0,
                                "text": str(linha['s']),
                            },
                        ],
                    },
                ],
            },
        ],
    }
    squad['data'].append(estrutura)

# Save the JSON to a file
with open('googleTrad2.json', 'w', encoding='utf-8') as json_file:
    json.dump(squad, json_file, ensure_ascii=False, indent=2)
# Out:
# Primeira linha da planilha:
# Unnamed: 0                                                      0
# title                                            E-mail marketing
# question        que é o uso mais comum de marketing por e-mail...
# long_answer     Um exemplo comum de marketing de permissão é u...
# short_answer    uma newsletter enviada aos clientes de uma emp...
# Name: 0, dtype: object
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\dudua\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# c:\Users\dudua\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\Users\dudua\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 't'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6868\1716589712.py in <module>
#      14 for idx, linha in planilha.iterrows():
#      15     estrutura = {
# ---> 16         "title": str(linha['t']),  # Assuming there is a column named 't' for title
#      17         "paragraphs": [
#      18             {
#
# c:\Users\dudua\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     956
#     957         elif key_is_scalar:
# --> 958             return self._get_value(key)
#     959
#     960         if is_hashable(key):
#
# c:\Users\dudua\anaconda3\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#    1067
#    1068         # Similar to Index.get_value, but we do not fall back to positional
# -> 1069         loc = self.index.get_loc(label)
#    1070         return self.index._get_values_for_loc(self, loc, label)
#    1071
#
# c:\Users\dudua\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 't'

# %%
print('i')
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'Python 3.10.0' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
